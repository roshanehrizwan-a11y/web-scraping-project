# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/world-population/population-by-country/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")

print(table)
# Out:
# <table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":true,"sortable":true,"defaultSort":"#","pageSize":false}' data-sort-col="0" data-sort-dir="asc" id=""> <thead> <tr> <th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true"> <span>#</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true"> <span>Country (or dependency)</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Population 2026</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Yearly Change</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Net Change</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Density (P/KmÂ²)</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Land Area (KmÂ²)</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Migrants (net)</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Fert. Rate</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Median Age</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>Urban Pop %</span> </th><th class="border-e border-zinc-200 px-2 text-center align-middle border-b-3 py-1 font-semibold" data-sortable="true" data-type="number"> <span>World Share</span> </th> </tr> </thead> <tbody> <tr id="india"> <td class="border-e border-zinc-200 px-2 border-b py-1.5 text-start"> 1 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 font-bold text-start"> <a class="transition-colors text-primary hover:text-primary/80" data-astro-reload="true" href="/world-population/india-population/"> India </a> </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end font-bold" data-order="14766255760000" dir="ltr"> 1,476,625,576 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="87" dir="ltr"> 0.87% </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="127600510000" dir="ltr"> 12,760,051 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="4966469" dir="ltr"> 497 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="29731900000" dir="ltr"> 2,973,190 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="-4404560000" dir="ltr"> â440,456 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="19290" dir="ltr"> 1.93 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="292160" dir="ltr"> 29.2 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="3761" dir="ltr"> 37.6% </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 text-end" data-order="1779" dir="ltr"> 17.79% </td> </tr><tr id="china"> <td class="border-e border-zinc-200 px-2 border-b py-1.5 text-start"> 2 </td><td class="border-e border-zinc-200 px-2 border-b py-1.5 font-bold text-start"> <a class="transition-colors text-primary hover:text-primary/80" data-astro-reload="true" href="/world-population/china-populatio ...

# %%
rows = table.find_all("tr")

# %%
header_row = table.find("tr")

headers = [th.text.strip() for th in header_row.find_all("th")]
print(headers)
# Out:
# ['#', 'Country (or dependency)', 'Population 2026', 'Yearly Change', 'Net Change', 'Density (P/KmÂ²)', 'Land Area (KmÂ²)', 'Migrants (net)', 'Fert. Rate', 'Median Age', 'Urban Pop %', 'World Share']

# %%
data = []

for row in rows[1:]:
    cols = row.find_all("td")
    
    if len(cols) > 0:
        data.append([col.text.strip() for col in cols])

# %%
df = pd.DataFrame(data, columns=headers)

df.head()
# Out:
#    # Country (or dependency) Population 2026 Yearly Change    Net Change  \
# 0  1                   India   1,476,625,576         0.87%    12,760,051
# 1  2                   China   1,412,914,089      â0.22%  â3,182,005
# 2  3           United States     349,035,494         0.51%     1,759,687
# 3  4               Indonesia     287,886,782         0.76%     2,165,546
# 4  5                Pakistan     259,299,791          1.6%     4,080,237
#
#   Density (P/KmÂ²) Land Area (KmÂ²) Migrants (net) Fert. Rate Median Age  \
# 0              497        2,973,190     â440,456       1.93       29.2
# 1              150        9,388,211     â232,107       1.03       40.6
# 2               38        9,147,420      1,177,848       1.63       38.7
# 3              159        1,811,570      â39,472       2.08       30.7
# 4              336          770,880   â1,144,738       3.44       20.8
#
#   Urban Pop % World Share
# 0       37.6%      17.79%
# 1       68.7%      17.02%
# 2       83.1%       4.20%
# 3       60.3%       3.47%
# 4       34.7%       3.12%

# %%
print(df.shape)
print(df.columns)
df.head()
# Out:
# (234, 12)
# Index(['#', 'Country (or dependency)', 'Population 2026', 'Yearly Change',
#        'Net Change', 'Density (P/KmÂ²)', 'Land Area (KmÂ²)', 'Migrants (net)',
#        'Fert. Rate', 'Median Age', 'Urban Pop %', 'World Share'],
#       dtype='object')
#    # Country (or dependency) Population 2026 Yearly Change    Net Change  \
# 0  1                   India   1,476,625,576         0.87%    12,760,051
# 1  2                   China   1,412,914,089      â0.22%  â3,182,005
# 2  3           United States     349,035,494         0.51%     1,759,687
# 3  4               Indonesia     287,886,782         0.76%     2,165,546
# 4  5                Pakistan     259,299,791          1.6%     4,080,237
#
#   Density (P/KmÂ²) Land Area (KmÂ²) Migrants (net) Fert. Rate Median Age  \
# 0              497        2,973,190     â440,456       1.93       29.2
# 1              150        9,388,211     â232,107       1.03       40.6
# 2               38        9,147,420      1,177,848       1.63       38.7
# 3              159        1,811,570      â39,472       2.08       30.7
# 4              336          770,880   â1,144,738       3.44       20.8
#
#   Urban Pop % World Share
# 0       37.6%      17.79%
# 1       68.7%      17.02%
# 2       83.1%       4.20%
# 3       60.3%       3.47%
# 4       34.7%       3.12%

# %%
df = df.replace(",", "", regex=True)

# %%
df.to_csv("world_population.csv", index=False)
